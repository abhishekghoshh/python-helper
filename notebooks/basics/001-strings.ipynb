# %% [markdown]
# # Python Strings

# %% [markdown]
# Strings in python are surrounded by either single quotation marks, or double quotation marks.
#
# 'hello' is the same as "hello".
#
# You can display a string literal with the print() function:

# %%
print("Hello")
print('Hello')
# Out:
# Hello
# Hello

# %% [markdown]
# #### Quotes Inside Quotes
# You can use quotes inside a string, as long as they don't match the quotes surrounding the string:

# %%
print("It's alright")
print("He is called 'Johnny'")
print('He is called "Johnny"')
# Out:
# It's alright
# He is called 'Johnny'
# He is called "Johnny"

# %% [markdown]
# #### Multiline Strings
# You can assign a multiline string to a variable by using three quotes:

# %% [markdown]
# You can use three double quotes:

# %%
a = """Lorem ipsum dolor sit amet,
consectetur adipiscing elit,
sed do eiusmod tempor incididunt
ut labore et dolore magna aliqua."""
print(a)
# Out:
# Lorem ipsum dolor sit amet,
# consectetur adipiscing elit,
# sed do eiusmod tempor incididunt
# ut labore et dolore magna aliqua.

# %% [markdown]
# Or three single quotes:

# %%
a = '''Lorem ipsum dolor sit amet,
consectetur adipiscing elit,
sed do eiusmod tempor incididunt
ut labore et dolore magna aliqua.'''
print(a)
# Out:
# Lorem ipsum dolor sit amet,
# consectetur adipiscing elit,
# sed do eiusmod tempor incididunt
# ut labore et dolore magna aliqua.

# %% [markdown]
# #### Strings are Arrays
# Like many other popular programming languages, strings in Python are arrays of unicode characters.
#
# However, Python does not have a character data type, a single character is simply a string with a length of 1.
#
# Square brackets can be used to access elements of the string.

# %%
a = "Hello, World!"
print(a[1])
# Out:
# e

# %% [markdown]
# Since strings are arrays, we can loop through the characters in a string, with a `for` loop.

# %%
# Loop through the letters in the word "banana":

for x in "banana":
  print(x, end=" ")
# Out:
# b a n a n a

# %% [markdown]
# To get the length of a string, use the `len()` function.

# %%
# The len() function returns the length of a string:

a = "Hello, World!"
print(len(a))
# Out:
# 13

# %% [markdown]
# To check if a certain phrase or character is present in a string, we can use the keyword `in`.

# %%
# Check if "free" is present in the following text:

txt = "The best things in life are free!"
print("free" in txt)
# Out:
# True

# %% [markdown]
# To check if a certain phrase or character is NOT present in a string, we can use the keyword `not in`.

# %%
# Check if "expensive" is NOT present in the following text:

txt = "The best things in life are free!"
print("expensive" not in txt)
# Out:
# True

# %% [markdown]
# ### Slicing Strings

# %% [markdown]
# You can return a range of characters by using the slice syntax. </br>
# Specify the start index and the end index, separated by a colon, to return a part of the string.

# %%
# Get the characters from position 2 to position 5 (not included):

b = "Hello, World!"
print(b[2:5])
# Out:
# llo

# %% [markdown]
# #### Slice To the End
# By leaving out the end index, the range will go to the end:

# %%
# Get the characters from position 2, and all the way to the end:

b = "Hello, World!"
print(b[2:])
# Out:
# llo, World!

# %% [markdown]
# #### Negative Indexing
# Use negative indexes to start the slice from the end of the string:

# %%
'''
Get the characters:
From: "o" in "World!" (position -5)
To, but not included: "d" in "World!" (position -2):
'''

b = "Hello, World!"
print(b[-5:-2])
# Out:
# orl

# %% [markdown]
# #### Python has a set of built-in methods that you can use on strings.

# %% [markdown]
# The `upper()` method returns the string in upper case:

# %%
a = "Hello, World!"
print(a.upper())
# Out:
# HELLO, WORLD!

# %% [markdown]
# The `lower()` method returns the string in lower case:

# %%
a = "Hello, World!"
print(a.lower())
# Out:
# hello, world!

# %% [markdown]
# The `strip()` method removes any whitespace from the beginning or the end:

# %%
a = " Hello, World! "
print(a.strip()) # returns "Hello, World!"
# Out:
# Hello, World!

# %% [markdown]
# The `replace()` method replaces a string with another string:

# %%
a = "Hello, World!"
print(a.replace("H", "J"))
# Out:
# Jello, World!

# %% [markdown]
# The `split()` method returns a list where the text between the specified separator becomes the list items.

# %%
a = "Hello, World!"
print(a.split(",")) # returns ['Hello', ' World!']
# Out:
# ['Hello', ' World!']

# %% [markdown]
# #### String Concatenation
#
# To concatenate, or combine, two strings you can use the `+` operator.

# %%
a = "Hello"
b = "World"
c = a + " " + b
print(c)
# Out:
# Hello World

# %% [markdown]
# ## String Format
#
# We cannot combine strings and numbers like this:

# %%
age = 36
#This will produce an error:
txt = "My name is John, I am " + age
print(txt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 3
#       1 age = 36
#       2 #This will produce an error:
# ----> 3 txt = "My name is John, I am " + age
#       4 print(txt)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# But we can combine strings and numbers by using f-strings or the format() method!
#
# ### F-Strings
#
# `F-String` was introduced in Python 3.6, and is now the preferred way of formatting strings.
#
# To specify a string as an f-string, simply put an f in front of the string literal, and add curly brackets `{}` as placeholders for variables and other operations.

# %%
# Create an f-string:

age = 36
txt = f"My name is John, I am {age}"
print(txt)
# Out:
# My name is John, I am 36

# %% [markdown]
# #### Placeholders and Modifiers

# %%
# Add a placeholder for the price variable:

price = 59
txt = f"The price is {price} dollars"
print(txt)
# Out:
# The price is 59 dollars

# %% [markdown]
# A placeholder can include a modifier to format the value. </br>
# A modifier is included by adding a colon : followed by a legal formatting type, like `.2f` which means fixed point number with 2 decimals:

# %%
# Display the price with 2 decimals:

price = 59
txt = f"The price is {price:.2f} dollars"
print(txt)

price = 59.667
txt = f"The price is {price:.2f} dollars"
print(txt)
# Out:
# The price is 59.00 dollars
# The price is 59.67 dollars

# %% [markdown]
# You can also format a value directly without keeping it in a variable:

# %%
# Display the value 95 with 2 decimals:

txt = f"The price is {95:.2f} dollars"
print(txt)
# Out:
# The price is 95.00 dollars

# %% [markdown]
# #### Perform Operations in F-Strings

# %%
# Perform a math operation in the placeholder, and return the result:

txt = f"The price is {20 * 59} dollars"
print(txt)
# Out:
# The price is 1180 dollars

# %% [markdown]
# # Add taxes before displaying the price:
#
# price = 59
# tax = 0.25
# txt = f"The price is {price + (price * tax)} dollars"
# print(txt)

# %% [markdown]
# You can perform if...else statements inside the placeholders:

# %%
# Return "Expensive" if the price is over 50, otherwise return "Cheap":

price = 49
txt = f"It is very {'Expensive' if (price > 50) else 'Cheap'}"

print(txt)
# Out:
# It is very Cheap

# %% [markdown]
# #### Execute Functions in F-Strings
#
# You can execute functions inside the placeholder:

# %%
# Use the string method upper()to convert a value into upper case letters:

fruit = "apples"
txt = f"I love {fruit.upper()}"
print(txt)
# Out:
# I love APPLES

# %% [markdown]
# The function does not have to be a built-in Python method, you can create your own functions and use them:

# %%
# Create a function that converts feet into meters:
def myconverter(x):
  return x * 0.3048

txt = f"The plane is flying at a {myconverter(30000)} meter altitude"
print(txt)
# Out:
# The plane is flying at a 9144.0 meter altitude

# %% [markdown]
# #### More Modifiers
#
# At the beginning of this chapter we explained how to use the `.2f` modifier to format a number into a fixed point number with 2 decimals. </br>
# There are several other modifiers that can be used to format values:

# %%
# Use a comma as a thousand separator:
price = 59000
txt = f"The price is {price:,} dollars"
print(txt)
# Out:
# The price is 59,000 dollars

# %% [markdown]
# Here is a list of all the formatting types.

# %% [markdown]
# | Format         | Description                                                 | Example                       | Output                          |
# | -------------- | ----------------------------------------------------------- | ----------------------------- | ------------------------------- |
# | `:<`           | Left-aligns the value within the available space.           | `"{:<10}".format("Hi")`       | `Hi        `                    |
# | `:>`           | Right-aligns the value within the available space.          | `"{:>10}".format("Hi")`       | `        Hi`                    |
# | `:^`           | Centers the value within the available space.               | `"{:^10}".format("Hi")`       | `    Hi    `                    |
# | `:=`           | Forces the sign (`+`/`-`) to the far left before padding.   | `"{:=+10d}".format(42)`       | `+       42`                    |
# | `:+`           | Shows `+` for positive numbers and `-` for negative ones.   | `"{:+d}".format(5)`           | `+5`                            |
# | `:-`           | Shows `-` for negative numbers only (default).              | `"{:-d}".format(5)`           | `5`                             |
# | `: ` *(space)* | Adds a leading space for positive values; `-` for negative. | `"{: d}".format(5)`           | ` 5`                            |
# | `:,`           | Uses commas as thousand separators.                         | `"{:,}".format(1000000)`      | `1,000,000`                     |
# | `:_`           | Uses underscores as thousand separators.                    | `"{:_}".format(1000000)`      | `1_000_000`                     |
# | `:b`           | Converts number to binary.                                  | `"{:b}".format(10)`           | `1010`                          |
# | `:c`           | Converts integer to Unicode character.                      | `"{:c}".format(65)`           | `A`                             |
# | `:d`           | Decimal integer format.                                     | `"{:d}".format(255)`          | `255`                           |
# | `:e`           | Scientific notation with lowercase `e`.                     | `"{:e}".format(10000)`        | `1.000000e+04`                  |
# | `:E`           | Scientific notation with uppercase `E`.                     | `"{:E}".format(10000)`        | `1.000000E+04`                  |
# | `:f`           | Fixed-point number format.                                  | `"{:f}".format(3.14)`         | `3.140000`                      |
# | `:F`           | Same as `f` but `inf/nan` uppercase.                        | `"{:F}".format(float('inf'))` | `INF`                           |
# | `:g`           | General format (no unnecessary zeros).                      | `"{:g}".format(123.450)`      | `123.45`                        |
# | `:G`           | General format with uppercase `E` for scientific notation.  | `"{:G}".format(1e6)`          | `1E+06`                         |
# | `:o`           | Octal format.                                               | `"{:o}".format(10)`           | `12`                            |
# | `:x`           | Hexadecimal lowercase.                                      | `"{:x}".format(255)`          | `ff`                            |
# | `:X`           | Hexadecimal uppercase.                                      | `"{:X}".format(255)`          | `FF`                            |
# | `:n`           | Number format using locale settings.                        | `"{:n}".format(1000000)`      | Depends on locale (`1,000,000`) |
# | `:%`           | Converts value to percentage (x100) with `%` sign.          | `"{:%}".format(0.25)`         | `25.000000%`                    |

# %% [markdown]
# #### String format()
# Before Python 3.6 we used the `format()` method to format strings. </br>
# The `format()` method can still be used, but `f-strings` are faster and the preferred way to format strings. </br>
#
# The next examples in this page demonstrates how to format strings with the `format()` method. </br>
# The `format()` method also uses curly brackets as placeholders `{}`, but the syntax is slightly different: </br>

# %%
# Add a placeholder where you want to display the price:

price = 49
txt = "The price is {} dollars"
print(txt.format(price))
# Out:
# The price is 49 dollars

# %% [markdown]
# You can add parameters inside the curly brackets to specify how to convert the value:

# %%
# Format the price to be displayed as a number with two decimals:
txt = "The price is {:.2f} dollars"

# %% [markdown]
# #### Multiple Values
# If you want to use more values, just add more values to the format() method:

# %%
quantity = 3
itemno = 567
price = 49
myorder = "I want {} pieces of item number {} for {:.2f} dollars."
print(myorder.format(quantity, itemno, price))
# Out:
# I want 3 pieces of item number 567 for 49.00 dollars.

# %% [markdown]
# #### Index Numbers
# You can use index numbers (a number inside the curly brackets {0}) to be sure the values are placed in the correct placeholders:

# %%
quantity = 3
itemno = 567
price = 49
myorder = "I want {0} pieces of item number {1} for {2:.2f} dollars."
print(myorder.format(quantity, itemno, price))
# Out:
# I want 3 pieces of item number 567 for 49.00 dollars.

# %% [markdown]
# Also, if you want to refer to the same value more than once, use the index number:

# %%
age = 36
name = "John"
txt = "His name is {1}. {1} is {0} years old."
print(txt.format(age, name))
# Out:
# His name is John. John is 36 years old.

# %% [markdown]
# #### Named Indexes
# You can also use named indexes by entering a name inside the curly brackets {carname}, but then you must use names when you pass the parameter values txt.format(carname = "Ford"):

# %%
myorder = "I have a {carname}, it is a {model}."
print(myorder.format(carname = "Ford", model = "Mustang"))
# Out:
# I have a Ford, it is a Mustang.

# %% [markdown]
# ### Escape Character
#
# To insert characters that are illegal in a string, use an escape character. </br>
# An escape character is a backslash `\` followed by the character you want to insert. </br>
# An example of an illegal character is a double quote inside a string that is surrounded by double quotes: </br>

# %%
# You will get an error if you use double quotes inside a string that is surrounded by double quotes:

txt = "We are the so-called "Vikings" from the north."
# Out:
#   Cell In[35], line 3
#     txt = "We are the so-called "Vikings" from the north."
#                                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# To fix this problem, use the escape character `\"`:

# %%
# The escape character allows you to use double quotes when you normally would not be allowed:

txt = "We are the so-called \"Vikings\" from the north."
print(txt)
# Out:
# We are the so-called "Vikings" from the north.

# %% [raw]
# Python Escape Characters
#
# | Code   | Result           |
# |--------|------------------|
# | `\'`   | Single Quote     |
# | `\\`   | Backslash        |
# | `\n`   | New Line         |
# | `\r`   | Carriage Return  |
# | `\t`   | Tab              |
# | `\b`   | Backspace        |
# | `\f`   | Form Feed        |
# | `\ooo` | Octal value      |
# | `\xhh` | Hex value        |

# %% [markdown]
# ### String Methods
#
# > Note: All string methods return new values. They do not change the original string.

# %% [markdown]
# | Method        | Description                                                                 | Example                                 | Output                         |
# |---------------|-----------------------------------------------------------------------------|-----------------------------------------|---------------------------------|
# | **capitalize()** | Converts the first character to uppercase and the rest to lowercase.         | `"hello".capitalize()`                   | `Hello`                         |
# | **casefold()**   | Aggressively converts string to lowercase (stronger than `.lower()`).      | `"HELLO".casefold()`                     | `hello`                         |
# | **center()**     | Centers the string with a specified width using spaces by default.         | `"hi".center(6)`                         | `'  hi  '`                      |
# | **count()**      | Returns how many times a substring occurs in the string.                   | `"banana".count("a")`                    | `3`                             |
# | **encode()**     | Encodes the string using the specified encoding (UTF-8 by default).        | `"hi".encode()`                           | `b'hi'`                         |
# | **endswith()**   | Checks if the string ends with the specified suffix.                       | `"hello".endswith("lo")`                 | `True`                          |
# | **expandtabs()** | Replaces tab characters `\t` with spaces (default size = 8).               | `"a\tb".expandtabs(4)`                   | `'a   b'`                       |
# | **find()**       | Returns the index of first occurrence of substring, or `-1` if not found.  | `"banana".find("na")`                    | `2`                             |
# | **format()**     | Formats values into a string using `{}` placeholders.                      | `"Hi {}".format("Abhi")`                 | `Hi Abhi`                       |
# | **format_map()** | Same as format(), but takes a dictionary directly.                         | `"Hi {name}".format_map({"name":"A"})`   | `Hi A`                          |
# | **index()**      | Like `find()`, but raises an error if substring is not found.              | `"banana".index("na")`                   | `2`                             |
# | **isalnum()**    | True if all characters are alphanumeric.                                   | `"abc123".isalnum()`                     | `True`                          |
# | **isalpha()**    | True if all characters are alphabetic.                                     | `"Hello".isalpha()`                      | `True`                          |
# | **isascii()**    | True if all characters are ASCII.                                          | `"Hello".isascii()`                      | `True`                          |
# | **isdecimal()**  | True if all characters are decimal digits.                                 | `"123".isdecimal()`                      | `True`                          |
# | **isdigit()**    | True if all characters are digits.                                         | `"123".isdigit()`                        | `True`                          |
# | **isidentifier()** | True if string is valid Python identifier.                               | `"name1".isidentifier()`                 | `True`                          |
# | **islower()**    | True if all characters are lowercase.                                      | `"hello".islower()`                      | `True`                          |
# | **isnumeric()**  | True if string contains only numeric characters.                           | `"123".isnumeric()`                      | `True`                          |
# | **isprintable()**| True if all characters are printable.                                      | `"Hello".isprintable()`                  | `True`                          |
# | **isspace()**    | True if string contains only whitespace.                                   | `"   ".isspace()`                        | `True`                          |
# | **istitle()**    | True if string is in title case.                                           | `"Hello World".istitle()`                | `True`                          |
# | **isupper()**    | True if all characters are uppercase.                                      | `"HELLO".isupper()`                      | `True`                          |
# | **join()**       | Joins iterable items using the string as a separator.                      | `" ".join(["Hi","Abhi"])`                | `Hi Abhi`                       |
# | **ljust()**      | Left-justifies string using spaces (or a character).                       | `"hi".ljust(6)`                          | `'hi    '`                      |
# | **lower()**      | Converts string to lowercase.                                              | `"HELLO".lower()`                        | `hello`                         |
# | **lstrip()**     | Strips leading spaces or characters.                                       | `"  hi".lstrip()`                        | `hi`                            |
# | **maketrans()**  | Creates translation table for `translate()`.                               | `"abc".maketrans("a","A")`               | translation table               |
# | **partition()**  | Splits string into 3 parts: before, match, after.                          | `"a-b-c".partition("-")`                 | `('a','-','b-c')`               |
# | **replace()**    | Replaces occurrences of a substring.                                       | `"hello".replace("l","x")`               | `hexxo`                         |
# | **rfind()**      | Like find(), but searches from the right.                                  | `"banana".rfind("na")`                   | `4`                             |
# | **rindex()**     | Like index(), but from the right; errors if not found.                     | `"banana".rindex("na")`                  | `4`                             |
# | **rjust()**      | Right-justifies string.                                                    | `"hi".rjust(6)`                          | `'    hi'`                      |
# | **rpartition()** | Like partition(), but splits at last occurrence.                           | `"a-b-c".rpartition("-")`                | `('a-b','-','c')`               |
# | **rsplit()**     | Splits from the right.                                                     | `"a,b,c".rsplit(",")`                    | `['a','b','c']`                 |
# | **rstrip()**     | Removes spaces or characters from right side.                              | `"hi   ".rstrip()`                       | `'hi'`                          |
# | **split()**      | Splits string into list by separator.                                     | `"a,b,c".split(",")`                     | `['a','b','c']`                 |
# | **splitlines()** | Splits on line breaks into a list.                                         | `"a\nb".splitlines()`                    | `['a','b']`                     |
# | **startswith()** | True if string starts with given prefix.                                   | `"hello".startswith("he")`               | `True`                          |
# | **strip()**      | Removes leading & trailing spaces/characters.                              | `"  hi  ".strip()`                       | `hi`                            |
# | **swapcase()**   | Swaps uppercase to lowercase and vice-versa.                               | `"HeLLo".swapcase()`                     | `hEllO`                         |
# | **title()**      | Converts string to title case.                                             | `"hello world".title()`                  | `Hello World`                   |
# | **translate()**  | Translates characters using table from maketrans().                        | `"abc".translate({"a":"A"})`             | `Abc` (if table correct)        |
# | **upper()**      | Converts string to uppercase.                                              | `"hello".upper()`                        | `HELLO`                         |
# | **zfill()**      | Pads string on the left with zeros.                                        | `"7".zfill(3)`                           | `007`                           |

# %% [markdown]
# ## Python RegEx

# %% [markdown]
# A RegEx, or Regular Expression, is a sequence of characters that forms a search pattern. </br>
# RegEx can be used to check if a string contains the specified search pattern. </br>
#
# Python has a built-in package called `re`, which can be used to work with Regular Expressions.

# %% [markdown]
# #### RegEx in Python
# When you have imported the re module, you can start using regular expressions:

# %%
# Search the string to see if it starts with "The" and ends with "Spain":

import re

txt = "The rain in Spain"
x = re.search("^The.*Spain$", txt)
print(x)
# Out:
# <re.Match object; span=(0, 17), match='The rain in Spain'>

# %% [markdown]
# #### RegEx Functions
#
# The re module offers a set of functions that allows us to search a string for a match:

# %% [markdown]
# | Function    | Description                                                                                           | Example                                    | Output                 |
# | ----------- | ----------------------------------------------------------------------------------------------------- | ------------------------------------------ | ---------------------- |
# | `findall()` | Returns **all occurrences** of the pattern as a list. Useful when you want every match from a string. | `re.findall(r"\d+", "A12B34C")`            | `['12', '34']`         |
# | `search()`  | Searches the string and returns the **first Match object**. Useful for checking if a pattern exists.  | `re.search(r"cat", "the cat sat").group()` | `cat`                  |
# | `split()`   | Splits the string **at each match** of the regex pattern.                                             | `re.split(r"\s+", "a b   c d")`            | `['a', 'b', 'c', 'd']` |
# | `sub()`     | Replaces one or many matches with the provided replacement string.                                    | `re.sub(r"\d", "*", "a1b2c3")`             | `a*b*c*`               |

# %% [markdown]
# #### Metacharacters
# Metacharacters are characters with a special meaning:

# %% [markdown]
# | Character | Description                                                                      | Example                                     | Output                      |                       |                  |
# | --------- | -------------------------------------------------------------------------------- | ------------------------------------------- | --------------------------- | --------------------- | ---------------- |
# | `[]`      | Matches **any one character** inside the brackets. Creates a character class.    | `re.findall(r"[a-m]", "hello")`             | `['h', 'e', 'l', 'l']`      |                       |                  |
# | `\`       | Used to signal a **special sequence** (like `\d`, `\w`) or to escape characters. | `re.findall(r"\d", "a1b2c")`                | `['1', '2']`                |                       |                  |
# | `.`       | Matches **any character except newline**.                                        | `re.findall(r"he..o", "hello hero hezzo")`  | `['hello', 'hezzo']`        |                       |                  |
# | `^`       | Matches **start of the string**.                                                 | `re.findall(r"^Hi", "Hi there!")`           | `['Hi']`                    |                       |                  |
# | `$`       | Matches **end of the string**.                                                   | `re.findall(r"end$", "This is the end")`    | `['end']`                   |                       |                  |
# | `*`       | Matches **0 or more repetitions** of the pattern.                                | `re.findall(r"he.*o", "heo hello hezzo")`   | `['heo', 'hello', 'hezzo']` |                       |                  |
# | `+`       | Matches **1 or more repetitions** of the pattern.                                | `re.findall(r"he.+o", "heo hello hezzo")`   | `['hello', 'hezzo']`        |                       |                  |
# | `?`       | Matches **0 or 1 repetition** (optional).                                        | `re.findall(r"he.?o", "heo hello heyo")`    | `['heo', 'heyo']`           |                       |                  |
# | `{}`      | Matches **exact number of repetitions**.                                         | `re.findall(r"he.{2}o", "hello hezzo")`     | `['hello', 'hezzo']`        |                       |                  |
# | `         | `                                                                                | Logical OR — matches **either expression**. | `re.findall(r"cat           | dog", "cat and dog")` | `['cat', 'dog']` |
# | `()`      | Captures and groups patterns; allows extraction of specific parts.               | `re.findall(r"(he)(llo)", "hello")`         | `[('he', 'llo')]`           |                       |                  |

# %% [markdown]
# #### Flags
# You can add flags to the pattern when using regular expressions.

# %% [markdown]
# | Flag            | Shorthand | Description                                                                           | Example                                               | Output                                |                                   |
# | --------------- | --------- | ------------------------------------------------------------------------------------- | ----------------------------------------------------- | ------------------------------------- | --------------------------------- |
# | `re.ASCII`      | `re.A`    | Enables **ASCII-only** matching for `\w`, `\W`, `\b`, `\B`, `\d`, `\D`, `\s`, `\S`.   | `re.findall(r"\w", "hello✓", re.A)`                   | `['h','e','l','l','o']` *(✓ ignored)* |                                   |
# | `re.DEBUG`      | —         | Prints **debug information** about the compiled regex. Useful for debugging patterns. | `re.compile(r"(a                                      | b)*c", re.DEBUG)`                     | *(Shows debug output in console)* |
# | `re.DOTALL`     | `re.S`    | Makes `.` match **every character**, including newline `\n`.                          | `re.findall(r"a.+c", "a\nb\nc", re.S)`                | `['a\nb\nc']`                         |                                   |
# | `re.IGNORECASE` | `re.I`    | Enables **case-insensitive** matching.                                                | `re.findall(r"hello", "Hello hELLo", re.I)`           | `['Hello', 'hELLo']`                  |                                   |
# | `re.MULTILINE`  | `re.M`    | Makes `^` and `$` match **start/end of each line**, not just entire string.           | `re.findall(r"^hi", "hi\nhello\nhi", re.M)`           | `['hi', 'hi']`                        |                                   |
# | `re.NOFLAG`     | —         | Specifies **no flags** (default). Demonstrates when flags are not applied.            | `re.findall(r"hello", "Hello")`                       | `[]` *(case-sensitive)*               |                                   |
# | `re.UNICODE`    | `re.U`    | Makes `\w`, `\d`, `\s` use **Unicode rules** (default in Python 3).                   | `re.findall(r"\w", "hello✓")`                         | `['h','e','l','l','o','✓']`           |                                   |
# | `re.VERBOSE`    | `re.X`    | Allows **spaces and comments** in regex for readability.                              | `re.findall(r''' \d+  # number ''', "Age: 24", re.X)` | `['24']`                              |                                   |

# %% [markdown]
# #### Special Sequences
# A special sequence is a \ followed by one of the characters in the list below, and has a special meaning:

# %% [markdown]
# | Character | Description                                                                                               | Example                                        | Output                      |
# | --------- | --------------------------------------------------------------------------------------------------------- | ---------------------------------------------- | --------------------------- |
# | `\A`      | Matches **only at the beginning of the entire string**. Unlike `^`, it is not affected by multiline mode. | `re.findall(r"\AThe", "The rain in Spain")`    | `['The']`                   |
# | `\b`      | Matches a **word boundary** at the beginning or end of a word. Useful for detecting whole-word matches.   | `re.findall(r"\bain", "ain goes in the rain")` | `['ain', 'ain']`            |
# |           |                                                                                                           | `re.findall(r"ain\b", "main pain gain")`       | `['ain', 'ain', 'ain']`     |
# | `\B`      | Matches when the position is **NOT at a word boundary** (middle of a word).                               | `re.findall(r"\Bain", "main pain gain")`       | `['ain']`                   |
# |           |                                                                                                           | `re.findall(r"ain\B", "aint rain again")`      | `['ain']`                   |
# | `\d`      | Matches **any digit** (0–9). Equivalent to `[0-9]`.                                                       | `re.findall(r"\d", "Room 204")`                | `['2','0','4']`             |
# | `\D`      | Matches **any non-digit** character. Opposite of `\d`.                                                    | `re.findall(r"\D", "A1B2C3")`                  | `['A','B','C']`             |
# | `\s`      | Matches **any whitespace** (space, tab, newline).                                                         | `re.findall(r"\s", "a b\tc\n")`                | `[' ', '\t', '\n']`         |
# | `\S`      | Matches **any NON-whitespace** character.                                                                 | `re.findall(r"\S", "a b\tc")`                  | `['a','b','c']`             |
# | `\w`      | Matches **word characters**: A–Z, a–z, 0–9, and `_`.                                                      | `re.findall(r"\w", "Hi_123!")`                 | `['H','i','_','1','2','3']` |
# | `\W`      | Matches **non-word characters**. Opposite of `\w`.                                                        | `re.findall(r"\W", "Hi_123!")`                 | `['!']`                     |
# | `\Z`      | Matches **only at the end of the string**.                                                                | `re.findall(r"Spain\Z", "I live in Spain")`    | `['Spain']`                 |

# %% [markdown]
# #### Sets
# A set is a set of characters inside a pair of square brackets `[]` with a special meaning:

# %% [markdown]
# | Set            | Description                                                                                 | Example                                             | Output                   |
# |----------------|---------------------------------------------------------------------------------------------|-----------------------------------------------------|---------------------------|
# | `[arn]`        | Matches **any one of the characters**: a, r, or n.                                          | `re.findall(r"[arn]", "rain")`                     | `['r', 'a', 'n']`        |
# | `[a-n]`        | Matches **any lowercase letter** from a to n (alphabetical range).                          | `re.findall(r"[a-n]", "Python and Java")`          | `['n', 'a', 'n', 'a']`   |
# | `[^arn]`       | Matches **any character except** a, r, or n (negated set).                                  | `re.findall(r"[^arn]", "rain")`                    | `['i']`                  |
# | `[0123]`       | Matches **any one of the digits** 0, 1, 2, or 3.                                            | `re.findall(r"[0123]", "123789")`                  | `['1', '2', '3']`        |
# | `[0-9]`        | Matches **any digit** from 0–9.                                                             | `re.findall(r"[0-9]", "A1B2C3")`                   | `['1', '2', '3']`        |
# | `[0-5][0-9]`   | Matches **any two-digit number** from 00 to 59 (like minutes).                               | `re.findall(r"[0-5][0-9]", "Time: 42 mins")`       | `['42']`                 |
# | `[a-zA-Z]`     | Matches **any letter**, lowercase a–z or uppercase A–Z.                                     | `re.findall(r"[a-zA-Z]", "Hello 123")`             | `['H','e','l','l','o']`  |
# | `[+]`          | Matches the literal plus sign `+` (because special chars lose meaning inside sets).         | `re.findall(r"[+]", "a+b=c")`                      | `['+']`                  |

# %% [markdown]
# #### The findall() Function
# The `findall()` function returns a list containing all matches.

# %%
# Print a list of all matches:

import re

txt = "The rain in Spain"
x = re.findall("ai", txt)
print(x)
# Out:
# ['ai', 'ai']

# %% [markdown]
# The list contains the matches in the order they are found. </br>
# If no matches are found, an empty list is returned: </br>

# %%
# Return an empty list if no match was found:

import re

txt = "The rain in Spain"
x = re.findall("Portugal", txt)
print(x)
# Out:
# []

# %% [markdown]
# #### The search() Function
#
# The `search()` function searches the string for a match, and returns a Match object if there is a match. </br>
# If there is more than one match, only the first occurrence of the match will be returned: </br>

# %%
# Search for the first white-space character in the string:

import re

txt = "The rain in Spain"
x = re.search("\s", txt)

print("The first white-space character is located in position:", x.start())
# Out:
# The first white-space character is located in position: 3

# %% [markdown]
# If no matches are found, the value `None` is returned:

# %%
# Make a search that returns no match:

import re

txt = "The rain in Spain"
x = re.search("Portugal", txt)
print(x)
# Out:
# None

# %% [markdown]
# #### The split() Function
# The `split()` function returns a list where the string has been split at each match:

# %%
# Split at each white-space character:

import re

txt = "The rain in Spain"
x = re.split("\s", txt)
print(x)
# Out:
# ['The', 'rain', 'in', 'Spain']

# %% [markdown]
# You can control the number of occurrences by specifying the `maxsplit` parameter:

# %% [markdown]
# # Split the string only at the first occurrence:
#
# import re
#
# txt = "The rain in Spain"
# x = re.split("\s", txt, 1)
# print(x)

# %% [markdown]
# #### The sub() Function
# The `sub()` function replaces the matches with the text of your choice:

# %%
# Replace every white-space character with the number 9:

import re

txt = "The rain in Spain"
x = re.sub("\s", "9", txt)
print(x)
# Out:
# The9rain9in9Spain

# %% [markdown]
# You can control the number of replacements by specifying the `count` parameter:

# %%
# Replace the first 2 occurrences:

import re

txt = "The rain in Spain"
x = re.sub("\s", "9", txt, 2)
print(x)
# Out:
# The9rain9in Spain

# %% [markdown]
# ### Match Object
#
# A Match Object is an object containing information about the search and the result. </br>
# **Note**: If there is no match, the value `None` will be returned, instead of the Match Object.

# %%
# Do a search that will return a Match Object:

import re

txt = "The rain in Spain"
x = re.search("ai", txt)
print(x) #this will print an object
# Out:
# <re.Match object; span=(5, 7), match='ai'>

# %% [markdown]
# The `Match object` has properties and methods used to retrieve information about the search, and the result:
# - `span()` returns a tuple containing the start-, and end positions of the match.
# - `string` returns the string passed into the function
# - `group()` returns the part of the string where there was a match

# %%
# Print the position (start- and end-position) of the first match occurrence.
# The regular expression looks for any words that starts with an upper case "S":

import re

txt = "The rain in Spain"
x = re.search(r"\bS\w+", txt)
print(x.span())
# Out:
# (12, 17)

# %%
# Print the string passed into the function:

import re

txt = "The rain in Spain"
x = re.search(r"\bS\w+", txt)
print(x.string)
# Out:
# The rain in Spain

# %%
# Print the part of the string where there was a match.
# The regular expression looks for any words that starts with an upper case "S":

import re

txt = "The rain in Spain"
x = re.search(r"\bS\w+", txt)
print(x.group())
# Out:
# Spain

# %% [markdown]
# > Note: If there is no match, the value None will be returned, instead of the Match Object.
