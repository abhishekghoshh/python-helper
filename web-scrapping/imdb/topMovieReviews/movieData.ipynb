# %%
import json,os
f=open(r"C:\Users\ASUS\Desktop\python\my_project\imdb project\top250MovieReviews\top250Movies.json","r")
for movies in f:
    movies=json.loads(movies)

# %%
import numpy as np
keys=list(movies.keys())
metadata=[]
gross=[]
votes=[]
rates=[]
values={}
for key in movies:
    vote=(movies[key])['vote']
    rate=(movies[key])['ratings']
    votes.append(vote)
    rates.append(rate)
    metadata.append(vote*rate)
    gross.append((movies[key])['gross'])
    values[key]=vote*rate

# keys=np.array(keys,dtype=object)
# metadata=np.array(metadata)
# gross=np.array(gross)
# votes=np.array(gross)
# rates=np.array(rates)

# %%
movies
# Out:
# {'1': {'name': 'The Shawshank Redemption',
#   'id': 'tt0111161',
#   'year': 1994,
#   'certificate': 'R',
#   'runtime': 142,
#   'genre': 'Drama',
#   'ratings': 9.3,
#   'metascore': 80,
#   'director': 'Frank Darabont',
#   'vote': 2002148,
#   'gross': 28341469},
#  '2': {'name': 'The Godfather',
#   'id': 'tt0068646',
#   'year': 1972,
#   'certificate': 'R',
#   'runtime': 175,
#   'genre': 'Crime, Drama',
#   'ratings': 9.2,
#   'metascore': 100,
#   'director': 'Francis Ford Coppola',
#   'vote': 1371645,
#   'gross': 134966411},
#  '3': {'name': 'The Dark Knight',
#   'id': 'tt0468569',
#   'year': 2008,
#   'certificate': 'PG-13',
#   'runtime': 152,
#   'genre': 'Action, Crime, Drama',
#   'ratings': 9.0,
#   'metascore': 84,
#   'director': 'Christopher Nolan',
#   'vote': 1971317,
#   'gross': 534858444},
#  '4': {'name': 'The Godfather: Part II',
#   'id': 'tt0071562',
#   'year': 1974,
#   'certificate': 'R',
#   'runtime': 202,
#   'genre': 'Crime, Drama',
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(keys,metadata)

# %%
import operator

sorted_values = sorted(values.items(), key=operator.itemgetter(1))

# %%
for

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-c798b51f730b> in <module>()
# ----> 1 sorted_keys=sorted_values[0,:]
#       2 sorted_keys
#
# TypeError: list indices must be integers or slices, not tuple
